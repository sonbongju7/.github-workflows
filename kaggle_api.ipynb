# %% [markdown]
# <a href="https://colab.research.google.com/github/sonbongju7/.github-workflows/blob/main/kaggle_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2982dc3c-e9b4-4797-998f-3f5f145c4b32" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2982dc3c-e9b4-4797-998f-3f5f145c4b32">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Kaggle API 라이브러리 설치
# !pip install kaggle

# Kaggle API 인증을 위해 json 파일을 적절한 위치에 복사
import os
import shutil

# kaggle.json 파일을 ~/.kaggle 폴더로 이동
os.makedirs('/root/.kaggle', exist_ok=True)
shutil.move('kaggle.json', '/root/.kaggle/kaggle.json')
# Out:
# ...
# '/root/.kaggle/kaggle.json'

# %%
# Titanic 데이터셋 다운로드 (dataset URL: https://www.kaggle.com/c/titanic)
# !kaggle competitions download -c titanic
# Out:
# ...
#   0% 0.00/34.1k [00:00<?, ?B/s]
# 100% 34.1k/34.1k [00:00<00:00, 42.6MB/s]

# %%
# 다운로드한 파일의 압축 해제
import zipfile

with zipfile.ZipFile('titanic.zip', 'r') as zip_ref:
    zip_ref.extractall('titanic_data')

# %%
import pandas as pd

# CSV 파일 경로 설정
train_path = 'titanic_data/train.csv'
test_path = 'titanic_data/test.csv'

# 데이터셋 로드
train_df = pd.read_csv(train_path)
test_df = pd.read_csv(test_path)

# 데이터프레임의 상위 5개 행을 출력하여 확인
print(train_df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Iris 데이터셋 다운로드 (dataset URL: https://www.kaggle.com/uciml/iris)
# !kaggle datasets download -d uciml/iris
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/uciml/iris
# License(s): CC0-1.0
# ...
#   0% 0.00/3.60k [00:00<?, ?B/s]
# 100% 3.60k/3.60k [00:00<00:00, 8.83MB/s]

# %%
# 다운로드한 파일의 압축 해제
import zipfile

with zipfile.ZipFile('iris.zip', 'r') as zip_ref:
    zip_ref.extractall('iris_data')

# %%
import pandas as pd

# CSV 파일 경로 설정
iris_path = 'iris_data/Iris.csv'

# 데이터셋 로드
iris_df = pd.read_csv(iris_path)

# 데이터프레임의 상위 5개 행을 출력하여 확인
print(iris_df.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...
